# %% [markdown]
# what is Statistics?
#
# It's a branch of science which involves collecting, analyzing, exploring, visualizing data in large quantities,
# so that we can come up with various use cases.
# Final Goal is to come up with meaningfull information.
#
#
# ## Topics
# 1) Stat
# 2) Descriptive
# 3) Inferential
# 4) Population
# 5) Sample
# 6) Sampling technique
# 7) Measure of central tendency
# 8) Measure of Variance/Dispersion
# 9) Probablity
# 10) permutation and combination
#
#
# ### Type of stat
#
# 1) Descriptive
#
# 2) Inferential
#
#
# **Descriptive Stat :** Focus on Analysing, exploring, visualizing with diff technique.
#                        Basically we do all the things to *understand the data*
#                        Organising and summerising the data
#                        Tool------ Histogram/bar/pie graph,
#                        most imp tool---- matplotlib, seaborn, tableau, powerbi, plotly
#
#
# **Infrential Stat :**  Population --> Sample of data --> Experiment --> Conclusion
#                        Basically final aim is to *get the conclusion*
#                        Here hypothesis testing come into the picture- p-value, t test, f test, z test.... etc

# %% [markdown]
# ## 4 & 5------- Population and Sample
#
#
# Let's take example:
# Exit poll(before result of election news channel showcase their exit poll): suppose in up we have population of 20 cr so the news guy can not goes to all the person(20 cr) so it will create some sample from data(mini data) then goes to the person, this mini data is sample
#
# In simple word- population is all the data and sampleis subset of population
#
# Population is denoted by **capital *N***
# Sample is denotes by **small *n***
#
# These sample is depend on hypothesis testing
#
#
# ## Sampling technique--
# 1) **Random Sampling**---- They are randomly getting selected
#
# Disadvnatages---
# a) Overlapping(sometime you choose one person many time)
# b) For specific use case
# c) Youtube channel subscriber
#
#
# 2) **Stratified Sampling**-------population is divided into sub groups(divide the data)
# exp-
# a)for exit polls goes to male
# b)for household expenditure goes to female
#
#
#
# 3) **Systematic Sampling**---------
# We check the nth person.
# like in exist pool--- somone is considered as n=10
# so they will ask the every 10 person to check the result
#
#
#
#
# 4) **Clustering Sampling**--------population is divided into multiple clusters.
#
#
# **Diff b/w startified and clustering : **
#
# Stratified---mean layering(it works on sub group)---- Gender data----- so divide in male and female group-- Homogenous
# Clustering---mean cluster ----------Gender data------ multiple cluster(1,2,3) each cluster have all kind of data-- Hactrogenous

# %%
# Where we use Sampling technique?

In train_test_split we have to divide the data,here we use random_sample=100 and like this so here we can use these tech as 
Random/Stratified/Cluster and all

# %% [markdown]
# ## 7- Measure of Central Tendency-
#
#
# Mean
# Median
# Mode
#
#
#
# Exp- Data: {1,2,3,4,100}
# **Whenever we have outliers in our data do not use mean to find out the average**, for this we should use **Median**
#
# Median does not get impacted by outliers
#
# Mode is also use when you have outliers
#
# But now question is when to use Median and when Mode?--------- will give this answer after some point.

# %% [markdown]
# ### Random Variables**---
#
# Exp1)
# ---- Pack of card------- Person 1 and person 2
# so who will get J first----(so it's totally depend on random)
#
# Exp2)
# -- Tossing a coin----------- What we get head or tail?(random varaible)
#
# **So there are two type of Random Variable**
# 1) Qualitative/Categorical Variable:
#         Two types
#         1.a) Nominal (No rank)---exp-) Gender-- Male/Femal
#         1.b) Ordering(Rank)------exp-) Weekdays- son,mon.....
#
#
#
# 2) Quantiative/Continuous Varaible:
#         Basicall have two type
#         2.a) Discrete quantiative var(whole numbers)----- Complete no---- exp: No of children in a family{1,2,3,4,2,3}<it can't be in decimal>
#         2.b) Continuous quantiative var(float/Real numbers)-----Fractional point---exp: Age{22.5, 32.3, 12.4} or Wight{76.5,43.6}......
#
# exp--- Temp? - contonuous discrete
#        pincode? categorical/Qualitiative(Nominal Type)
#        days? - categorical(ordering)

# %% [markdown]
# **So Now come to the question when we should use median or mode?**
#
# Exp1)
# No of childern-{1,2,3,nan,3,1,4,1,nan,4,5,2,3,12....}----(Continuous variable)
#
# so to fill the nan value we should use mean/median/mode
# mean------ Don't use when we have outlier(12)
# mode------ we should use mode in this case
# median----- then why not median? bcoz the result can be in fraction(and it's not possible to give fraction of children)
#
#
#
# Median can only apply to numerical value bcoz it gives float values also.
